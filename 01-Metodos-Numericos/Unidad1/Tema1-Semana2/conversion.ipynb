# %% [markdown]
# Apartado C: Programación y conversión numérica en Python
#
# Desarrollar un programa en Python que convierta un número decimal entero
# a binario mediante divisiones sucesivas.

# %%
def decimal_a_binario(n):
    if n == 0:
        return "0"

    residuos = []
    while n > 0:
        residuos.append(str(n % 2))
        n //= 2

    return "".join(reversed(residuos))

entrada = input("Ingrese un numero decimal entero: ").strip()
numero = int(entrada) if entrada else 0

print("Decimal:", numero)
print("Binario:", decimal_a_binario(numero))
# Out:
# Decimal: 1125
# Binario: 10001100101
