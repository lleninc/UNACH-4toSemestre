# %%
import numpy as np

edades = np.array([22, 21, 20, 19, 26, 24, 23, 20, 21, 25])
promedio = np.mean(edades)

print("Edades:", edades)
print("Promedio de edades:", promedio)
# Out:
# Edades: [22 21 20 19 26 24 23 20 21 25]
# Promedio de edades: 22.1
